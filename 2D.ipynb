# %%
import google.generativeai as genai
import json

genai.configure(api_key="AIzaSyDzCtqbx-JLchi4KzqNJl7BXnudIX5sytk")

model = genai.GenerativeModel("gemini-2.5-pro-exp-03-25")

prompt = """
You are a professional architectural planner.

Your task is to generate a complete and readable 2D floor plan as structured JSON for a blueprint renderer.

🏠 House Requirements:
Include these rooms:

5 Bedrooms

2 Bathrooms

1 Kitchen

1 Dining Room

1 Living Room

1 Garage

1 Hallway

1 Storage

1 Walk-in Closet

📏 Layout Constraints:
All rooms must fit neatly within a canvas of 800×600 pixels

No overlapping rooms

Leave at least 4 pixels of spacing between rooms

No room smaller than 40×40 pixels

Use "x", "y" for top-left coordinates, and "width", "height" (in pixels)

🧱 Room Structure:
Each room must include:

json
Copy
Edit
{
"name": "Bedroom 1",
"type": "bedroom",
"x": 100,
"y": 100,
"width": 120,
"height": 100,
"label_lines": ["BEDROOM 1", "CARPET", "CLG @ 8'"],
"show_dimensions": true,
"outer_walls": ["top", "left"],
"doors": [
{ "side": "bottom", "offset": 30, "swing": "right" }
],
"fixtures": [
{ "type": "sink", "x": 10, "y": 10 },
{ "type": "toilet", "x": 30, "y": 10 }
]
}
label_lines: 2–3 lines for blueprint-style text

show_dimensions: if true, renderer shows room width × height inside room

outer_walls: sides that are on the outer edge of the house (e.g., "left", "top")

doors: each with side, offset, and swing direction (in, out, left, right)

fixtures: only for bathrooms/kitchens; includes relative x, y within room

🧠 Additional Rules:
Use logical, livable room adjacencies (e.g. kitchen near dining, bedrooms grouped)

Prioritize clarity and structure over realism — output must be renderable

✅ Return only the JSON array of rooms.
❌ Do not include any explanations, comments, or SVG.
"""

response = model.generate_content(prompt)

floorplan_raw = response.text

clean_text = re.sub(r'^```json|```$', '', floorplan_raw.strip(), flags=re.MULTILINE).strip()

try:
    floorplan_json = json.loads(clean_text)
    print("✅ JSON successfully parsed and stored in 'floorplan_json'")
except json.JSONDecodeError:
    print("⚠️ Could not parse JSON. Raw response stored in 'floorplan_raw'")
    floorplan_json = None
    floorplan_raw = floorplan_raw
