# %%
import os; os.environ['GEMINI_API_KEY'] = 'AIzaSyDzCtqbx-JLchi4KzqNJl7BXnudIX5sytk'

# %%
import base64
import os
from google import genai
from google.genai import types


def save_binary_file(file_name, data):
    f = open(file_name, "wb")
    f.write(data)
    f.close()


def generate():
    client = genai.Client(
        api_key=os.environ.get("GEMINI_API_KEY"),
    )

    files = [
        # Make the file available in local system working directory
        client.files.upload(file="plan.jpg"),
    ]
    model = "gemini-2.0-flash-exp-image-generation"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_uri(
                    file_uri=files[0].uri,
                    mime_type=files[0].mime_type,
                ),
                types.Part.from_text(text="""
                
                You are a professional architectural planner.

Use the uploaded image only as layout inspiration — do not include any furniture.

Generate a simple 2D architectural floor plan with only the following labeled rooms:

5 Bedrooms

2 Bathrooms

1 Kitchen

1 Dining Room

1 Living Room

1 Garage

1 Hallway

1 Storage Room

1 Walk-in Closet


"""),
            ],
        )
    ]
    generate_content_config = types.GenerateContentConfig(
        temperature=1,
        top_p=0.95,
        top_k=40,
        max_output_tokens=20000,
        response_modalities=[
            "image",
            "text",
        ],
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_CIVIC_INTEGRITY",
                threshold="OFF",  # Off
            ),
        ],
        response_mime_type="text/plain",
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        if not chunk.candidates or not chunk.candidates[0].content or not chunk.candidates[0].content.parts:
            continue
        if chunk.candidates[0].content.parts[0].inline_data:
            file_name = "output.jpg"
            save_binary_file(
                file_name, chunk.candidates[0].content.parts[0].inline_data.data
            )
            print(
                "File of mime type"
                f" {chunk.candidates[0].content.parts[0].inline_data.mime_type} saved"
                f"to: {file_name}"
            )
        else:
            print(chunk.text)

if __name__ == "__main__":
    generate()
# Out:
# File of mime type image/png savedto: output.jpg
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In [11], line 101
#      98             print(chunk.text)
#     100 if __name__ == "__main__":
# --> 101     generate()
#
# Cell In [11], line 80, in generate()
#      23 contents = [
#      24     types.Content(
#      25         role="user",
#    (...)
#      60     )
#      61 ]
#      62 generate_content_config = types.GenerateContentConfig(
#      63     temperature=1,
#      64     top_p=0.95,
#    (...)
#      77     response_mime_type="text/plain",
#      78 )
# ---> 80 for chunk in client.models.generate_content_stream(
#      81     model=model,
#      82     contents=contents,
#      83     config=generate_content_config,
#      84 ):
#      85     if not chunk.candidates or not chunk.candidates[0].content or not chunk.candidates[0].content.parts:
#      86         continue
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/google/genai/models.py:5079, in Models.generate_content_stream(self, model, contents, config)
#    5073 function_map = _extra_utils.get_function_map(config)
#    5075 if i == 1:
#    5076   # First request gets a function call.
#    5077   # Then get function response parts.
#    5078   # Yield chunks only if there's no function response parts.
# -> 5079   for chunk in response:
#    5080     if not function_map:
#    5081       yield chunk
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/google/genai/models.py:3988, in Models._generate_content_stream(self, model, contents, config)
#    3985 request_dict = _common.convert_to_dict(request_dict)
#    3986 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3988 for response_dict in self._api_client.request_streamed(
#    3989     'post', path, request_dict, http_options
#    3990 ):
#    3992   if self._api_client.vertexai:
#    3993     response_dict = _GenerateContentResponse_from_vertex(
#    3994         self._api_client, response_dict
#    3995     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/google/genai/_api_client.py:675, in BaseApiClient.request_streamed(self, http_method, path, request_dict, http_options)
#     670 http_request = self._build_request(
#     671     http_method, path, request_dict, http_options
#     672 )
#     674 session_response = self._request(http_request, stream=True)
# --> 675 for chunk in session_response.segments():
#     676   yield chunk
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/google/genai/_api_client.py:199, in HttpResponse.segments(self)
#     197 if chunk.startswith('data: '):
#     198   chunk = chunk[len('data: ') :]
# --> 199 yield json.loads(chunk)
#
# File ~/opt/anaconda3/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/opt/anaconda3/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/opt/anaconda3/lib/python3.9/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
